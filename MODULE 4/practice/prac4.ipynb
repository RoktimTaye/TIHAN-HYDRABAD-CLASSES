# %%
import os
import torch
from torch import nn
from torch.utils.data import dataloader
from torchvision import datasets,transforms

device = torch.accelerator.current_accelerator().type if torch.accelerator.is_available() else "cpu"
print(f"Using {device} device")
# Out:
# Using cpu device

# %%
class Neural_Network(nn.Module):
    def __init__(self):
        super().__init__()
        self.flatten = nn.Flatten()
        self.linar_relu_stack = nn.Sequential(
            nn.Linear(28*28,512),
            nn.ReLU(),
            nn.Linear(512,512),
            nn.ReLU(),
            nn.Linear(512,10)
        )

    def forward(self,x):
        x = self.flatten(x)
        logits = self.linar_relu_stack(x)
        return logits

# %%
model = Neural_Network().to(device)
print(model)
# Out:
# Neural_Network(
#   (flatten): Flatten(start_dim=1, end_dim=-1)
#   (linar_relu_stack): Sequential(
#     (0): Linear(in_features=784, out_features=512, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=512, out_features=512, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=512, out_features=10, bias=True)
#   )
# )

# %%
x= torch.rand(1,28,28,device=device)
logits = model(x)
pred_probab = nn.Softmax(dim=1)(logits)
y_pred = pred_probab.argmax(1)
print(f"Predicted class : {y_pred}")
# Out:
# Predicted class : tensor([7])

# %%
input_image = torch.rand(3,28,28)
print(input_image.size())
# Out:
# torch.Size([3, 28, 28])

# %%
flatten = nn.Flatten()
flat_image = flatten(input_image)
print(flat_image.size())
# Out:
# torch.Size([3, 784])

# %%
layer1 = nn.Linear(in_features=28*28,out_features=20)
hidden1 = layer1(flat_image)
print(hidden1.size())
# Out:
# torch.Size([3, 20])

# %%
print(f"Before ReLU: {hidden1}\n\n")
hidden1 = nn.ReLU()(hidden1)
print(f"After ReLU: {hidden1}")
# Out:
# Before ReLU: tensor([[-0.3649, -0.2145,  0.8321, -0.1566,  0.1033, -0.2650,  0.2829,  0.3618,
#          -0.1318,  0.1618, -0.5923,  1.0144, -0.0375, -0.0842,  0.0481,  0.2289,
#           0.3057,  0.4031,  0.1823, -0.4667],
#         [-0.2156, -0.1736,  0.6851, -0.2329,  0.4183, -0.5027,  0.3712,  0.2232,
#          -0.2201,  0.0858, -0.5550,  0.6624,  0.2481, -0.2631, -0.1145,  0.2370,
#           0.4321,  0.2377,  0.1405, -0.1208],
#         [-0.3238, -0.1464,  0.6561, -0.5678,  0.3036, -0.0028,  0.3806,  0.4302,
#          -0.2633,  0.0531, -0.6448,  0.6559, -0.5811, -0.5386, -0.3331,  0.0929,
#           0.0262,  0.2839,  0.1150, -0.5183]], grad_fn=<AddmmBackward0>)
#
#
# After ReLU: tensor([[0.0000, 0.0000, 0.8321, 0.0000, 0.1033, 0.0000, 0.2829, 0.3618, 0.0000,
#          0.1618, 0.0000, 1.0144, 0.0000, 0.0000, 0.0481, 0.2289, 0.3057, 0.4031,
#          0.1823, 0.0000],
#         [0.0000, 0.0000, 0.6851, 0.0000, 0.4183, 0.0000, 0.3712, 0.2232, 0.0000,
#          0.0858, 0.0000, 0.6624, 0.2481, 0.0000, 0.0000, 0.2370, 0.4321, 0.2377,
#          0.1405, 0.0000],
#         [0.0000, 0.0000, 0.6561, 0.0000, 0.3036, 0.0000, 0.3806, 0.4302, 0.0000,
#          0.0531, 0.0000, 0.6559, 0.0000, 0.0000, 0.0000, 0.0929, 0.0262, 0.2839,
#          0.1150, 0.0000]], grad_fn=<ReluBackward0>)

# %%
seq_modules = nn.Sequential(
    flatten,
    layer1,
    nn.ReLU(),
    nn.Linear(20, 10)
)
input_image = torch.rand(3,28,28)
logits = seq_modules(input_image)

# %%
softmax = nn.Softmax(dim=1)
pred_probab = softmax(logits)
model
# Out:
# Neural_Network(
#   (flatten): Flatten(start_dim=1, end_dim=-1)
#   (linar_relu_stack): Sequential(
#     (0): Linear(in_features=784, out_features=512, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=512, out_features=512, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=512, out_features=10, bias=True)
#   )
# )

# %%
for name,param in model.named_parameters():
    print(f"Layer: {name} | Size: {param.size()} | Values : {param[:2]} \n")
# Out:
# Layer: linar_relu_stack.0.weight | Size: torch.Size([512, 784]) | Values : tensor([[ 0.0028,  0.0132, -0.0251,  ...,  0.0315, -0.0091,  0.0069],
#         [-0.0027, -0.0048,  0.0060,  ..., -0.0067,  0.0333, -0.0046]],
#        grad_fn=<SliceBackward0>)
#
# Layer: linar_relu_stack.0.bias | Size: torch.Size([512]) | Values : tensor([-0.0225,  0.0148], grad_fn=<SliceBackward0>)
#
# Layer: linar_relu_stack.2.weight | Size: torch.Size([512, 512]) | Values : tensor([[-0.0351,  0.0139,  0.0150,  ...,  0.0110, -0.0409, -0.0174],
#         [ 0.0024, -0.0226, -0.0223,  ..., -0.0372, -0.0379,  0.0025]],
#        grad_fn=<SliceBackward0>)
#
# Layer: linar_relu_stack.2.bias | Size: torch.Size([512]) | Values : tensor([0.0426, 0.0214], grad_fn=<SliceBackward0>)
#
# Layer: linar_relu_stack.4.weight | Size: torch.Size([10, 512]) | Values : tensor([[-0.0189, -0.0005, -0.0252,  ...,  0.0276,  0.0337,  0.0220],
#         [-0.0392,  0.0017, -0.0002,  ..., -0.0230, -0.0104, -0.0389]],
#        grad_fn=<SliceBackward0>)
#
# Layer: linar_relu_stack.4.bias | Size: torch.Size([10]) | Values : tensor([0.0085, 0.0172], grad_fn=<SliceBackward0>)
