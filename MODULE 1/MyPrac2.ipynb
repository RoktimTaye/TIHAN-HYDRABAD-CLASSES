# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
MyDf = pd.read_csv('Cars.csv')
MyDf
# Out:
#     Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0       ritz  2014           3.35           5.59       27000    Petrol
# 1        sx4  2013           4.75           9.54       43000    Diesel
# 2       ciaz  2017           7.25           9.85        6900    Petrol
# 3    wagon r  2011           2.85           4.15        5200    Petrol
# 4      swift  2014           4.60           6.87       42450    Diesel
# ..       ...   ...            ...            ...         ...       ...
# 296     city  2016           9.50          11.60       33988    Diesel
# 297     brio  2015           4.00           5.90       60000    Petrol
# 298     city  2009           3.35          11.00       87934    Petrol
# 299     city  2017          11.50          12.50        9000    Diesel
# 300     brio  2016           5.30           5.90        5464    Petrol
#
#     Seller_Type Transmission  Owner
# 0        Dealer       Manual      0
# 1        Dealer       Manual      0
# ...

# %%
MyDf.describe()
# Out:
#               Year  Selling_Price  Present_Price     Kms_Driven       Owner
# count   301.000000     301.000000     301.000000     301.000000  301.000000
# mean   2013.627907       4.661296       7.628472   36947.205980    0.043189
# std       2.891554       5.082812       8.644115   38886.883882    0.247915
# min    2003.000000       0.100000       0.320000     500.000000    0.000000
# 25%    2012.000000       0.900000       1.200000   15000.000000    0.000000
# 50%    2014.000000       3.600000       6.400000   32000.000000    0.000000
# 75%    2016.000000       6.000000       9.900000   48767.000000    0.000000
# max    2018.000000      35.000000      92.600000  500000.000000    3.000000

# %%
MyDf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 301 entries, 0 to 300
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Car_Name       301 non-null    object
#  1   Year           301 non-null    int64
#  2   Selling_Price  301 non-null    float64
#  3   Present_Price  301 non-null    float64
#  4   Kms_Driven     301 non-null    int64
#  5   Fuel_Type      301 non-null    object
#  6   Seller_Type    301 non-null    object
#  7   Transmission   301 non-null    object
#  8   Owner          301 non-null    int64
# dtypes: float64(2), int64(3), object(4)
# memory usage: 21.3+ KB

# %%
MyDf.isnull().sum()
# Out:
# Car_Name         0
# Year             0
# Selling_Price    0
# Present_Price    0
# Kms_Driven       0
# Fuel_Type        0
# Seller_Type      0
# Transmission     0
# Owner            0
# dtype: int64

# %%
plt.Figure(figsize=(8,6))
plt.plot(MyDf['Present_Price'])
plt.plot(MyDf['Selling_Price'])
plt.xlabel('Price Category')
plt.ylabel('Price')
plt.show()

# %%
plt.scatter(MyDf['Selling_Price'], MyDf['Present_Price'])
plt.xlabel('Index')
plt.ylabel('Price')
plt.show()

# %%
plt.bar(MyDf['Fuel_Type'].value_counts()
        .index,MyDf['Fuel_Type']
        .value_counts(),
        color=['green','blue','red'])
# Out:
# <BarContainer object of 3 artists>

# %%
plt.figure(figsize=(8,6))
ax = plt.subplot(111,projection='polar')
ax.scatter(MyDf['Present_Price'],MyDf['Kms_Driven'])
plt.show()

# %%
fig,axs = plt.subplots(1, 3, sharex=True,figsize=(15, 5))
axs[0].boxplot(MyDf['Kms_Driven'])
axs[1].boxplot(MyDf['Present_Price'])
axs[2].boxplot(MyDf['Selling_Price'])
plt.show()

# %%
plt.hist(MyDf['Selling_Price'],bins=5,edgecolor='black')
plt.show()

# %%
MyDf2 = sns.load_dataset('tips')
CorrMatrix = MyDf2.corr(numeric_only=True)
sns.heatmap(CorrMatrix,annot=True,cmap='coolwarm',fmt='.2f')
plt.show()

# %%
sns.clustermap(CorrMatrix,annot=True,cmap='coolwarm',fmt='.2f')
plt.show()

# %%
numerical_cols = MyDf2.select_dtypes(include=['float64','int64']).columns
pairplot = sns.pairplot(MyDf2)
plt.show()

# %%
numerical_cols = MyDf2.select_dtypes(include=['float64','int64']).columns
pairplot = sns.pairplot(MyDf2,
             hue='smoker',
             diag_kind='kde',
             kind='reg')
plt.show()

# %%
df = sns.load_dataset('tips')
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
#Normal Scattered plotting
plt.figure(figsize=(8, 5))
sns.scatterplot(
    data=df,
    x="total_bill",
    y="tip",
    size="size",
    hue="time",
    sizes=(20, 1000),
    alpha=0.6,
    edgecolor="w",
    linewidth=0.5
)
#Annotation for Highest point 
highest_bill_row = df.loc[df['total_bill'].idxmax()] #Storing max value in a variable for Annotating max point
plt.annotate(
    'Highest Bill',
    xy=(highest_bill_row['total_bill'],highest_bill_row['tip']), # **arrow annotating
    xytext=(highest_bill_row['total_bill']+5,highest_bill_row['tip']+1), # **Text annotating
    arrowprops=dict(facecolor='black',shrink=0.05),
    fontsize=10,
    color='red'
)
#Annotation for Lowest point
highest_bill_row = df.loc[df['total_bill'].idxmin()] #Storing min value in a variable for Annotating min point
plt.annotate(
    'Highest Bill',
    xy=(highest_bill_row['total_bill'],highest_bill_row['tip']), # **arrow annotating
    xytext=(highest_bill_row['total_bill']-5,highest_bill_row['tip']+0.5), # **Text annotating
    arrowprops=dict(facecolor='black',shrink=0.05),
    fontsize=10,
    color='green',
    horizontalalignment='right' #By default the annotation alignment is right to left so we need to make it left to ride direction
)
plt.show()
