# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('Cars.csv')
df
# Out:
#     Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0       ritz  2014           3.35           5.59       27000    Petrol
# 1        sx4  2013           4.75           9.54       43000    Diesel
# 2       ciaz  2017           7.25           9.85        6900    Petrol
# 3    wagon r  2011           2.85           4.15        5200    Petrol
# 4      swift  2014           4.60           6.87       42450    Diesel
# ..       ...   ...            ...            ...         ...       ...
# 296     city  2016           9.50          11.60       33988    Diesel
# 297     brio  2015           4.00           5.90       60000    Petrol
# 298     city  2009           3.35          11.00       87934    Petrol
# 299     city  2017          11.50          12.50        9000    Diesel
# 300     brio  2016           5.30           5.90        5464    Petrol
#
#     Seller_Type Transmission  Owner
# 0        Dealer       Manual      0
# 1        Dealer       Manual      0
# 2        Dealer       Manual      0
# 3        Dealer       Manual      0
# 4        Dealer       Manual      0
# ..          ...          ...    ...
# 296      Dealer       Manual      0
# 297      Dealer       Manual      0
# 298      Dealer       Manual      0
# 299      Dealer       Manual      0
# 300      Dealer       Manual      0
#
# [301 rows x 9 columns]

# %%
plt.plot(df['Selling_Price'],label = 'Selling Price')
plt.plot(df['Present_Price'],label = 'Present Price')
plt.legend()
plt.show()

# %%
plt.scatter(df['Present_Price'],df['Selling_Price'])
plt.show()

# %%
plt.bar(df['Fuel_Type'].value_counts().index,df['Fuel_Type'].value_counts())
plt.show()

# %%
df['Present_Price'].value_counts().plot(kind='hist')
plt.legend()
plt.show()

# %%
plt.hist(df['Selling_Price'],bins=10,edgecolor = 'black')
plt.show()

# %%
df['Present_Price'].value_counts().plot(kind='box')
# Out:
# <Axes: >

# %%
fig,axs = plt.subplots(1, 3, sharex=True,figsize=(15, 5))
#1 row → all plots will be placed horizontally.
#3 columns → three separate plotting areas (called axes) are created side by side.
axs[0].boxplot(df['Selling_Price'])
axs[1].boxplot(df['Present_Price'])
axs[2].boxplot(df['Kms_Driven'])
plt.show()

# %%
# figure = plt.Figure(figsize=(8,5))
# data = figure.add_subplot(projection = 'polar')
# data.scatter(df['Selling_Price'],df['Kms_Driven'])
# plt.show()
figure=plt.figure(figsize=(8,6))
data1=figure.add_subplot(projection='polar')
data1.scatter(df['Selling_Price'],df['Kms_Driven'])
# plt.title('Polar Projection: Selling Price vs Kms Driven')
plt.show()
