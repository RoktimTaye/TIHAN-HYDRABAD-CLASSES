# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('Cars.csv')
df
# Out:
#     Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0       ritz  2014           3.35           5.59       27000    Petrol
# 1        sx4  2013           4.75           9.54       43000    Diesel
# 2       ciaz  2017           7.25           9.85        6900    Petrol
# 3    wagon r  2011           2.85           4.15        5200    Petrol
# 4      swift  2014           4.60           6.87       42450    Diesel
# ..       ...   ...            ...            ...         ...       ...
# 296     city  2016           9.50          11.60       33988    Diesel
# 297     brio  2015           4.00           5.90       60000    Petrol
# 298     city  2009           3.35          11.00       87934    Petrol
# 299     city  2017          11.50          12.50        9000    Diesel
# 300     brio  2016           5.30           5.90        5464    Petrol
#
#     Seller_Type Transmission  Owner
# 0        Dealer       Manual      0
# 1        Dealer       Manual      0
# ...

# %%
df.describe()
# Out:
#               Year  Selling_Price  Present_Price     Kms_Driven       Owner
# count   301.000000     301.000000     301.000000     301.000000  301.000000
# mean   2013.627907       4.661296       7.628472   36947.205980    0.043189
# std       2.891554       5.082812       8.644115   38886.883882    0.247915
# min    2003.000000       0.100000       0.320000     500.000000    0.000000
# 25%    2012.000000       0.900000       1.200000   15000.000000    0.000000
# 50%    2014.000000       3.600000       6.400000   32000.000000    0.000000
# 75%    2016.000000       6.000000       9.900000   48767.000000    0.000000
# max    2018.000000      35.000000      92.600000  500000.000000    3.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 301 entries, 0 to 300
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Car_Name       301 non-null    object
#  1   Year           301 non-null    int64
#  2   Selling_Price  301 non-null    float64
#  3   Present_Price  301 non-null    float64
#  4   Kms_Driven     301 non-null    int64
#  5   Fuel_Type      301 non-null    object
#  6   Seller_Type    301 non-null    object
#  7   Transmission   301 non-null    object
#  8   Owner          301 non-null    int64
# dtypes: float64(2), int64(3), object(4)
# memory usage: 21.3+ KB

# %%
df.isnull().sum()
# Out:
# Car_Name         0
# Year             0
# Selling_Price    0
# Present_Price    0
# Kms_Driven       0
# Fuel_Type        0
# Seller_Type      0
# Transmission     0
# Owner            0
# dtype: int64

# %% [markdown]
# LINE PLOT

# %%
plt.figure(figsize=(8, 6))
plt.plot(df['Selling_Price'], color='green',marker='o')
plt.xlabel('Index')
plt.ylabel('Selling Price')
plt.title('Selling Price line graph')
plt.show()

# %%
plt.figure(figsize=(8, 6))
plt.plot(df['Selling_Price'], color='green',marker='o')
plt.plot(df['Present_Price'], color='blue', marker='x')
plt.xlabel('Index')
plt.ylabel('Price')
plt.legend(['Selling Price', 'Present Price'])
plt.title('Selling Price vs Present Price')
plt.show()

# %%
plt.bar(df['Fuel_Type'].value_counts().index,df['Fuel_Type'].value_counts(),color=['red', 'blue', 'green'])
plt.title('Fuel Type Bar Graph')
plt.xlabel('Fuel Type')
plt.ylabel('Count')
legends = ['Petrol', 'Diesel', 'CNG']
plt.legend(legends)
plt.show()

# %%
plt.scatter(df['Selling_Price'], df['Present_Price'], color='green', marker='o')
plt.title('Selling Price vs Present Price Scatter Plot')
plt.xlabel('Index')
plt.ylabel('Price')
plt.legend(['Selling Price', 'Present Price'])
plt.show()

# %%
df.select_dtypes(include='number').hist(bins=5, edgecolor='black')
plt.show()

# %%
plt.hist(df['Selling_Price'])
plt.title('Histogram of Selling Price')
plt.xlabel('Selling Price')
plt.ylabel('Frequency')
plt.show()

# %%
plt.figure(figsize=(8,6))
ax = plt.subplot(111, projection='polar')
ax.scatter(df['Selling_Price'], df['Kms_Driven'])  # Selling price as angle, km driven as radius
plt.title('Polar Plot: Selling Price vs Kilometers Driven')
plt.show()

# %%
plt.boxplot(df['Selling_Price'])
plt.title('Box Plot of Selling Price')
plt.ylabel('Price')
plt.show()

# %%
plt.boxplot([df['Selling_Price']], labels=['Selling Price'])
plt.boxplot([df['Present_Price']], labels=['Present Price'])
plt.title('Box Plots Comparison')
plt.ylabel('Price')
plt.xlabel('Both Selling Category')
# Out:
# C:\Users\Roktim\AppData\Local\Temp\ipykernel_6876\675711304.py:1: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot([df['Selling_Price']], labels=['Selling Price'])
# C:\Users\Roktim\AppData\Local\Temp\ipykernel_6876\675711304.py:2: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot([df['Present_Price']], labels=['Present Price'])
# Text(0.5, 0, 'Both Selling Category')

# %%
plt.scatter(df['Year'], df['Selling_Price'])
plt.xlabel('Year')
plt.ylabel('Selling Price')
plt.title('Dot Plot of Selling Price vs Year')
plt.show()
